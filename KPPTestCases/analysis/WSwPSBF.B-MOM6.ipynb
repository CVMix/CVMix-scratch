# %% [markdown]
# <h1 align="center">MOM6 diagnostics for KPP single column test case</h1>
#
#  Results from this notebook:
# 1. Basic diagnostics of KPP boundary layer and prognostic fields, comparing various vertical resolution results.
#
# Caveats regarding this notebook:
# 1. This notebook is written for the MOM6-examples/ocean_only/SCM_KPP_tests.
#
# Hopes for the use of this notebook:
# 1. To provide a starting point to document single column model tests;
# 2. To illustrate a self-contained iPython notebook of use for MOM6 analysis.
#
# This iPython notebook was originally developed at NOAA/GFDL, and it is provided freely to the MOM6 community. GFDL scientists developing MOM6 make extensive use of Python for diagnostics. We solicit modifications/fixes that are useful to the MOM6 community.

# %%
import matplotlib.pyplot as plt                  # For plotting
import netCDF4                                   # For reading data
#import PyFerret as ferret 
pylab.rcParams['figure.figsize'] = (17.0, 10.0)  # Large figures

expt_name = 'WSwPSBF_B'

path_20cm = '../WSwPSBF.B20cm/'
path_1m   = '../WSwPSBF.B1m/'
path_10m  = '../WSwPSBF.B10m/'
path_cm4  = '../WSwPSBF.BCM4/'
#path = './'

deltaz_20cm = '20cm'
deltaz_1m   = '1m'
deltaz_10m  = '10m'
deltaz_cm4  = 'CM4'

fname_deltaz_20cm = '_20cm'
fname_deltaz_1m   = '_1m'
fname_deltaz_10m  = '_10m'
fname_deltaz_cm4  = '_CM4'

dpi=200

# %%
visc = netCDF4.Dataset(path_20cm+'visc.nc')

# recall data layout is (t,z,y,x)

time = visc.variables['Time'][:]

# KPP boundary layer depth as function of time (metre)
h_20cm = visc.variables['KPP_OBLdepth'][:,0,0]

# KPP tracer diffusivity as function of time and depth (m2/sec)
Kt_20cm = visc.variables['KPP_Kheat'][:,:,0,0]

# KPP velocity diffusivity as function of time and depth (m2/sec)
Ku_20cm = visc.variables['KPP_Kv'][:,:,0,0]

# surface (and penetrating) buoyancy flux, as used by [CVmix] KPP (m2/s3)
KPP_buoyFlux_20cm = visc.variables['KPP_buoyFlux'][:,:,0,0]

# Temperature tendency due to non-local transport of heat, as calculated by KPP (K/s)
KPP_dTdt_20cm = visc.variables['KPP_dTdt'][:,:,0,0]


prog  = netCDF4.Dataset(path_20cm+'prog.nc')
   
# depth of cell interface     
zi_20cm = prog.variables['zi'][:]

# depth of cell center 
zl_20cm = prog.variables['zl'][:]

# zonal velocity as function of time and depth
u_20cm  = prog.variables['u'][:,:,0,0]

# zonal velocity as function of time and depth
v_20cm  = prog.variables['v'][:,:,0,0]

# temperature as function of time and depth 
temp_20cm = prog.variables['temp'][:,:,0,0]

# %%
visc = netCDF4.Dataset(path_1m+'visc.nc')

# recall data layout is (t,z,y,x)

time = visc.variables['Time'][:]

# KPP boundary layer depth as function of time (metre)
h_1m = visc.variables['KPP_OBLdepth'][:,0,0]

# KPP tracer diffusivity as function of time and depth (m2/sec)
Kt_1m = visc.variables['KPP_Kheat'][:,:,0,0]

# KPP velocity diffusivity as function of time and depth (m2/sec)
Ku_1m = visc.variables['KPP_Kv'][:,:,0,0]

# surface (and penetrating) buoyancy flux, as used by [CVmix] KPP (m2/s3)
KPP_buoyFlux_1m = visc.variables['KPP_buoyFlux'][:,:,0,0]

# Temperature tendency due to non-local transport of heat, as calculated by KPP (K/s)
KPP_dTdt_1m = visc.variables['KPP_dTdt'][:,:,0,0]



prog  = netCDF4.Dataset(path_1m+'prog.nc')
   
# depth of cell interface     
zi_1m = prog.variables['zi'][:]

# depth of cell center 
zl_1m = prog.variables['zl'][:]

# zonal velocity as function of time and depth
u_1m  = prog.variables['u'][:,:,0,0]

# zonal velocity as function of time and depth
v_1m  = prog.variables['v'][:,:,0,0]

# temperature as function of time and depth 
temp_1m = prog.variables['temp'][:,:,0,0]

# %%
visc = netCDF4.Dataset(path_10m+'visc.nc')

# recall data layout is (t,z,y,x)

time = visc.variables['Time'][:]

# KPP boundary layer depth as function of time (metre)
h_10m = visc.variables['KPP_OBLdepth'][:,0,0]

# KPP tracer diffusivity as function of time and depth (m2/sec)
Kt_10m = visc.variables['KPP_Kheat'][:,:,0,0]

# KPP velocity diffusivity as function of time and depth (m2/sec)
Ku_10m = visc.variables['KPP_Kv'][:,:,0,0]

# surface (and penetrating) buoyancy flux, as used by [CVmix] KPP (m2/s3)
KPP_buoyFlux_10m = visc.variables['KPP_buoyFlux'][:,:,0,0]

# Temperature tendency due to non-local transport of heat, as calculated by KPP (K/s)
KPP_dTdt_10m = visc.variables['KPP_dTdt'][:,:,0,0]



prog  = netCDF4.Dataset(path_10m+'prog.nc')
   
# depth of cell interface     
zi_10m = prog.variables['zi'][:]

# depth of cell center 
zl_10m = prog.variables['zl'][:]

# zonal velocity as function of time and depth
u_10m  = prog.variables['u'][:,:,0,0]

# zonal velocity as function of time and depth
v_10m  = prog.variables['v'][:,:,0,0]

# temperature as function of time and depth 
temp_10m = prog.variables['temp'][:,:,0,0]

for v in visc.variables: print v,
# Out:
# xh yh zi Time nv zl xq yq Kd_interface KPP_uStar KPP_buoyFlux KPP_QminusSW KPP_netSalt KPP_OBLdepth KPP_sigma KPP_BulkRi KPP_Ws KPP_N KPP_N2 KPP_Vt2 KPP_BulkUz2 KPP_BulkDrho KPP_Kd_in KPP_Kheat KPP_Ksalt KPP_Kv KPP_NLtransport_heat KPP_NLtransport_salt KPP_dTdt KPP_dSdt KPP_Tsurf KPP_Ssurf KPP_Usurf KPP_Vsurf MLD_003 average_T1 average_T2 average_DT Time_bounds

# %%
visc = netCDF4.Dataset(path_cm4+'visc.nc')

# recall data layout is (t,z,y,x)

time = visc.variables['Time'][:]

# KPP boundary layer depth as function of time (metre)
h_cm4 = visc.variables['KPP_OBLdepth'][:,0,0]

# KPP tracer diffusivity as function of time and depth (m2/sec)
Kt_cm4 = visc.variables['KPP_Kheat'][:,:,0,0]

# KPP velocity diffusivity as function of time and depth (m2/sec)
Ku_cm4 = visc.variables['KPP_Kv'][:,:,0,0]

# surface (and penetrating) buoyancy flux, as used by [CVmix] KPP (m2/s3)
KPP_buoyFlux_cm4 = visc.variables['KPP_buoyFlux'][:,:,0,0]

# Temperature tendency due to non-local transport of heat, as calculated by KPP (K/s)
KPP_dTdt_cm4 = visc.variables['KPP_dTdt'][:,:,0,0]



prog  = netCDF4.Dataset(path_cm4+'prog.nc')
   
# depth of cell interface     
zi_cm4 = prog.variables['zi'][:]

# depth of cell center 
zl_cm4 = prog.variables['zl'][:]

# zonal velocity as function of time and depth
u_cm4  = prog.variables['u'][:,:,0,0]

# zonal velocity as function of time and depth
v_cm4  = prog.variables['v'][:,:,0,0]

# temperature as function of time and depth 
temp_cm4 = prog.variables['temp'][:,:,0,0]

# %%
# KPP diffusivity  


figure(1)
fig = plt.figure(figsize=(16,10), dpi=dpi)

plt.subplot(2,2,1)
data   = Kt_20cm
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zi_20cm
deltaz = deltaz_20cm 
CS = plt.pcolormesh(time, -depths, field.T, vmin=0.0, vmax=0.01)
plt.colorbar()
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $\kappa_{\Theta}$ ($m^2/s$) with $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(221)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)


plt.subplot(2,2,2)
data   = Kt_1m
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zi_1m
deltaz = deltaz_1m
CS = plt.pcolormesh(time, -depths, field.T, vmin=0.0, vmax=0.01)
plt.colorbar()
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $\kappa_{\Theta}$ ($m^2/s$) with $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(222)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)


plt.subplot(2,2,3)
data   = Kt_cm4
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zi_cm4
deltaz = deltaz_cm4
CS = plt.pcolormesh(time, -depths, field.T, vmin=0.0, vmax=0.01)
plt.colorbar()
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $\kappa_{\Theta}$ ($m^2/s$) with $\Delta z$ ='+deltaz,fontsize=24)
plt.xlabel('Time (days)',fontsize=24);
plot = fig.add_subplot(223)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)


plt.subplot(2,2,4)
data   = Kt_10m
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zi_10m
deltaz = deltaz_10m
CS = plt.pcolormesh(time, -depths, field.T, vmin=0.0, vmax=0.01)
plt.colorbar()
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $\kappa_{\Theta}$ ($m^2/s$) with $\Delta z$ ='+deltaz,fontsize=24)
plt.xlabel('Time (days)',fontsize=24);
plot = fig.add_subplot(224)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)


plt.tight_layout()
fname = expt_name+'_MOM6_KPP_diffusivity.png'
fig.savefig(fname,dpi=dpi);

# %%
# u velocity component 


figure(1)
fig = plt.figure(figsize=(16,10), dpi=dpi)

plt.subplot(2,2,1)
data   = u_20cm
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zl_20cm
deltaz = deltaz_20cm 
CS = plt.pcolormesh(time, -depths, field.T, vmin=-.1, vmax=0.1)
plt.colorbar()
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $u$ ($m/s$) with $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(221)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)


plt.subplot(2,2,2)
data   = u_1m
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zl_1m
deltaz = deltaz_1m
CS = plt.pcolormesh(time, -depths, field.T, vmin=-.1, vmax=0.1)
plt.colorbar()
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $u$ ($m/s$) with $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(222)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)


plt.subplot(2,2,3)
data   = u_cm4
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zl_cm4
deltaz = deltaz_cm4
CS = plt.pcolormesh(time, -depths, field.T, vmin=-.1, vmax=0.1)
plt.colorbar()
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $u$ ($m/s$) with $\Delta z$ ='+deltaz,fontsize=24)
plt.xlabel('Time (days)',fontsize=24);
plot = fig.add_subplot(223)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)


plt.subplot(2,2,4)
data   = u_10m
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zl_10m
deltaz = deltaz_10m
CS = plt.pcolormesh(time, -depths, field.T, vmin=-.1, vmax=0.1)
plt.colorbar()
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $u$ ($m/s$) with $\Delta z$ ='+deltaz,fontsize=24)
plt.xlabel('Time (days)',fontsize=24);
plot = fig.add_subplot(224)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)


plt.tight_layout()
fname = expt_name+'_MOM6_zonal_velocity.png'
fig.savefig(fname,dpi=dpi);

# %%
# temperature drift

figure(1)
fig = plt.figure(figsize=(16,10), dpi=dpi)

plt.subplot(2,2,1)
data   = temp_20cm[:,:] - temp_20cm[0,:]
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zl_20cm
deltaz = deltaz_20cm
CS = plt.pcolormesh(time, -depths, field.T, vmin=0, vmax=1.7)
plt.colorbar()
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $\Theta-\Theta(t=0)$ ($\degree$C) w/ $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(221)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)

plt.subplot(2,2,2)
data   = temp_1m[:,:] - temp_1m[0,:]
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zl_1m
deltaz = deltaz_1m
CS = plt.pcolormesh(time, -depths, field.T, vmin=0, vmax=1.7)
plt.colorbar()
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $\Theta-\Theta(t=0)$ ($\degree$C) w/ $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(222)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)

plt.subplot(2,2,3)
data   = temp_cm4[:,:] - temp_cm4[0,:]
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zl_cm4
deltaz = deltaz_cm4
CS = plt.pcolormesh(time, -depths, field.T, vmin=0, vmax=1.7)
plt.colorbar()
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.xlabel('Time (days)',fontsize=24)
plt.title(r'MOM6 $\Theta-\Theta(t=0)$ ($\degree$C) w/ $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(223)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)

plt.subplot(2,2,4)
data   = temp_10m[:,:] - temp_10m[0,:]
field  = np.ma.masked_array(data, mask=[data==0.])
depths = zl_10m
deltaz = deltaz_10m
#CS = plt.contourf(time, -depths, field.T, levels=numpy.arange(-.6,2,.02))
CS = plt.pcolormesh(time, -depths, field.T, vmin=0, vmax=1.7)
plt.colorbar()
#C = plt.contour(time, -depths, field.T, 8, linewidth=.5, colors='black')
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.xlabel('Time (days)',fontsize=24)
plt.title(r'MOM6 $\Theta-\Theta(t=0)$ ($\degree$C) w/ $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(224)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)

plt.tight_layout()
fname = expt_name+'_MOM6_temp_drift.png'
fig.savefig(fname,dpi=dpi);

# %%
# temperature 

figure(1)
fig = plt.figure(figsize=(16,10), dpi=dpi)

plt.subplot(2,2,1)
field = temp_20cm[:,:]
depths = zl_20cm
deltaz = deltaz_20cm
#CS = plt.contourf(time, -depths, field.T, levels=numpy.arange(14,17,.1))
CS = plt.pcolormesh(time, -depths, field.T, vmin=14.0, vmax=16.8)
plt.colorbar()
#C = plt.contour(time, -depths, field.T, levels=numpy.arange(14,17,.1), linewidth=.5, colors='black')
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $\Theta$ ($\degree$C) w/ $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(221)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)


plt.subplot(2,2,2)
field = temp_1m[:,:]
depths = zl_1m
deltaz = deltaz_1m
#CS = plt.contourf(time, -depths, field.T, levels=numpy.arange(14,17,.1))
CS = plt.pcolormesh(time, -depths, field.T, vmin=14.0, vmax=16.8)
plt.colorbar()
#C = plt.contour(time, -depths, field.T, levels=numpy.arange(14,17,.1), linewidth=.5, colors='black')
plt.ylim((-50,0))
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $\Theta$ ($\degree$C) w/ $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(222)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)


plt.subplot(2,2,3)
field = temp_cm4[:,:]
depths = zl_cm4
deltaz = deltaz_cm4
#CS = plt.contourf(time, -depths, field.T, levels=numpy.arange(14,17,.1))
CS = plt.pcolormesh(time, -depths, field.T, vmin=14.0, vmax=16.8)
plt.colorbar()
#C = plt.contour(time, -depths, field.T, levels=numpy.arange(14,17,.1), linewidth=.5, colors='black')
plt.ylim((-50,0))
plt.xlabel('Time (days)',fontsize=24)
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $\Theta$ ($\degree$C) w/ $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(223)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)


plt.subplot(2,2,4)
field = temp_10m[:,:]
depths = zl_10m
deltaz = deltaz_10m
#CS = plt.contourf(time, -depths, field.T, levels=numpy.arange(14,17,.1))
CS = plt.pcolormesh(time, -depths, field.T, vmin=14.0, vmax=16.8)
plt.colorbar()
#C = plt.contour(time, -depths, field.T, levels=numpy.arange(14,17,.1), linewidth=.5, colors='black')
plt.ylim((-50,0))
plt.xlabel('Time (days)',fontsize=24)
plt.ylabel('z (m)',fontsize=24)
plt.title(r'MOM6 $\Theta$ ($\degree$C) w/ $\Delta z$ ='+deltaz,fontsize=24);
plot = fig.add_subplot(224)
plot.tick_params(axis='both', which='major', labelsize=18)
plot.tick_params(axis='both', which='minor', labelsize=18)



plt.tight_layout()
fname = expt_name+'_MOM6_temp.png'
fig.savefig(fname,dpi=dpi);

# %%
# Boundary layer depth

figure(1)
fig, ax = plt.subplots(figsize=(16, 10), dpi=dpi)

field = h_20cm
CS = plt.plot(time, -field,'-',linewidth=3, label=deltaz_20cm)
field = h_1m
CS = plt.plot(time, -field,'-',linewidth=3, label=deltaz_1m)
field = h_cm4
CS = plt.plot(time, -field,'-',linewidth=3, label=deltaz_cm4)
field = h_10m
CS = plt.plot(time, -field,'-',linewidth=3, label=deltaz_10m)
ax.legend(fontsize=24)

yticks = [-30, -20, -10, 0]
ax.set_yticks(yticks)
xticks = [0, 3, 6, 9, 12, 15]
ax.set_xticks(xticks)
plt.grid()
plt.xlabel('Time (days)',fontsize=30)
plt.ylabel('z (m)',fontsize=30)
plt.title(r'KPP boundary layer depth from MOM6',fontsize=30)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=30)
ax.set_xticklabels(["$%.1f$" % x for x in xticks], fontsize=30);

plt.tight_layout()
fname = expt_name+'_MOM6_KPP_bldepth.png'
fig.savefig(fname,dpi=dpi);

# %%
# SST

figure(1)
fig, ax = plt.subplots(figsize=(16, 10), dpi=dpi)

field = temp_20cm[:,0]
CS = plt.plot(time, field,'-',linewidth=3, label=deltaz_20cm)
field = temp_1m[:,0]
CS = plt.plot(time, field,'-',linewidth=3, label=deltaz_1m)
field = temp_cm4[:,0]
CS = plt.plot(time, field,'-',linewidth=3, label=deltaz_cm4)
field = temp_10m[:,0]
CS = plt.plot(time, field,'-',linewidth=3, label=deltaz_10m)

ax.legend(fontsize=24,loc='upper left')

yticks = [14.5, 15.0, 15.5, 16.0, 16.5]
ax.set_yticks(yticks)
xticks = [0, 3, 6, 9, 12, 15]
ax.set_xticks(xticks)
plt.grid()
plt.ylabel(r'SST ($\degree$C)',fontsize=30)
plt.xlabel('Time (days)',fontsize=30)
plt.title(r'SST from MOM6',fontsize=30)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=30)
ax.set_xticklabels(["$%.1f$" % x for x in xticks], fontsize=30);

plt.tight_layout()
fname = expt_name+'_MOM6_SST.png'
fig.savefig(fname,dpi=dpi);
